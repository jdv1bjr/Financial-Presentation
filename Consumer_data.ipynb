# %% [markdown]
# <a href="https://colab.research.google.com/github/jdv1bjr/Financial-Presentation/blob/main/Consumer_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import seaborn as sns
import pandas as pd
import math
import matplotlib.pyplot as plt

# %%
Consumer_df = pd.read_csv('CustomerConsumerData.csv')

Consumer_df.head(100)
# Out:
#     column1  Customer_City Customer_Country Customer_Email Customer_Fname  \
# 0     18673      Tonawanda          EE. UU.      XXXXXXXXX        Shellie
# 1     18676       New York          EE. UU.      XXXXXXXXX            Uta
# 2     18683        Yonkers          EE. UU.      XXXXXXXXX             Bo
# 3     18692       New York          EE. UU.      XXXXXXXXX      Gwendolyn
# 4     18693       Brooklyn          EE. UU.      XXXXXXXXX         Xerxes
# ..      ...            ...              ...            ...            ...
# 95     5478          Bronx          EE. UU.      XXXXXXXXX       Cherokee
# 96     5480       Brooklyn          EE. UU.      XXXXXXXXX           Judy
# 97     5482          Bronx          EE. UU.      XXXXXXXXX          Alice
# 98     5492          Bronx          EE. UU.      XXXXXXXXX         Robert
# 99     5502  Staten Island          EE. UU.      XXXXXXXXX           Mary
#
#     Customer_Id Customer_Lname Customer_Password Customer_Segment  \
# ...

# %%
city_counts_df = Consumer_df['Customer_City'].value_counts()

#city_counts.head(100)

city_counts.plot(kind='bar')

plt.title('Customer Demographic')
plt.xlabel('Customer City')
plt.ylabel('Number of Customers')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
